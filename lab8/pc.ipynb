# %%
# !nvcc lab8_1.cu -o lab8_1
# !./lab8_1
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# === Поэлементное умножение (GPU), первые 10 элементов ===
#   c[0] = 6.60 * 4.00 = 26.40
#   c[1] = 8.10 * 4.10 = 33.21
#   c[2] = 1.20 * 5.80 = 6.96
#   c[3] = 2.10 * 4.00 = 8.40
#   c[4] = 3.50 * 4.30 = 15.05
#   c[5] = 7.40 * 4.30 = 31.82
#   c[6] = 1.70 * 0.40 = 0.68
#   c[7] = 9.60 * 6.20 = 59.52
#   c[8] = 9.20 * 4.80 = 44.16
#   c[9] = 9.80 * 5.90 = 57.82
#
# === Поэлементное сложение: GPU vs CPU ===
# Первые 10 элементов:
#   a[0]=6.60  b[0]=4.00  GPU=10.60  CPU=10.60
#   a[1]=8.10  b[1]=4.10  GPU=12.20  CPU=12.20
#   a[2]=1.20  b[2]=5.80  GPU=7.00  CPU=7.00
#   a[3]=2.10  b[3]=4.00  GPU=6.10  CPU=6.10
#   a[4]=3.50  b[4]=4.30  GPU=7.80  CPU=7.80
#   a[5]=7.40  b[5]=4.30  GPU=11.70  CPU=11.70
#   a[6]=1.70  b[6]=0.40  GPU=2.10  CPU=2.10
#   a[7]=9.60  b[7]=6.20  GPU=15.80  CPU=15.80
# ...

# %%
# !nvcc lab8_2.cu -o lab8_2 && ./lab8_2
# !nvcc lab8_3.cu -o lab8_3 && ./lab8_3
# !nvcc -O2 lab8_4.cu -o lab8_4 && ./lab8_4
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# CUDA device count: 1
#
# === GPU 0: Tesla T4 ===
#
# --- Память ---
#   Глобальная память:             14912 МБ
#   Память констант:               64 КБ
#   Разделяемая память на блок:    48 КБ
#   Кэш L2:                        4096 КБ
#   Ширина шины памяти:            256 бит
#
# --- Вычисления ---
#   Версия вычислит. возможностей: 7.5
#   Число SM (мультипроцессоров):  40
#   Тактовая частота ядра:         1590 МГц
#   Частота памяти:                5001 МГц
#
# --- Потоки и блоки ---
#   Регистров на блок:             65536
#   Размер WARP:                   32
#   Макс. потоков в блоке:         1024
#   Макс. размер блока (x,y,z):    1024 x 1024 x 64
#   Макс. размер сетки (x,y,z):    2147483647 x 65535 x 65535
#
# --- Дополнительно ---
#   Одновременно копир. и вычисл.: 3
# ...
